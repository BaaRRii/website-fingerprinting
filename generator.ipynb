# %%
import numpy as np

class DistribucionEmpirica:
    def __init__(self, percentiles_definidos):
        """
        percentiles_definidos: diccionario con percentiles (0-100) como claves y valores en KB
        Ej: {10: 600, 25: 1385, 50: 2827, 75: 5252, 90: 9686}
        """
        self._construir_interpolador(percentiles_definidos)

    def _construir_interpolador(self, percentiles_definidos):
        # Convertir a listas ordenadas
        p_ordenados = sorted(percentiles_definidos.items())
        ps, vs = zip(*p_ordenados)

        # Asegurarse de tener extremos
        if 0 not in ps:
            ps = (0,) + ps
            vs = (vs[0] * 0.5,) + vs
        if 100 not in ps:
            ps = ps + (100,)
            vs = vs + (vs[-1] * 1.5,)

        # Guardar como percentiles 0-1
        self.percentiles = [p / 100 for p in ps]
        self.valores = list(vs)

    def muestra(self):
        u = np.random.rand()
        return np.interp(u, self.percentiles, self.valores)

    def muestras(self, n):
        u = np.random.rand(n)
        return np.interp(u, self.percentiles, self.valores)

# %%
total_kbytes = DistribucionEmpirica({
    10: 600,
    25: 1385,
    50: 2827,
    75: 5252,
    90: 9686
})

n_images = DistribucionEmpirica({
    10: 6,
    25: 21,
    50: 46,
    75: 102,
    90: 223
})

html_kbytes = DistribucionEmpirica({
    10: 8,
    25: 22,
    50: 64,
    75: 148,
    90: 292
})

# %%
total_size = total_kbytes.muestra()
num_images = int(n_images.muestra())
html_size = html_kbytes.muestra()

print(f"Total size: {total_size} KB")
print(f"Num images: {num_images}")
print(f"HTML size: {html_size} KB")
# Out:
# Total size: 4679.092756990574 KB
# Num images: 233
# HTML size: 198.42895745808886 KB

# %%
import os
import random
import struct
import numpy as np

def create_bmp(filename, target_size):
    height = 1
    if target_size < 54:
        raise ValueError(f"El tamaño deseado ({target_size}) es menor que el tamaño mínimo de un BMP (54 bytes)")

    # Calcular pixel_bytes ajustado al múltiplo de 3 más cercano hacia abajo
    pixel_bytes = (target_size - 54) // 3 * 3
    width = pixel_bytes // 3
    file_size = 54 + pixel_bytes
    
    with open(filename, 'wb') as f:
        f.write(b'BM')
        f.write(struct.pack('<I', file_size))
        f.write(b'\x00\x00\x00\x00')
        f.write(b'\x36\x00\x00\x00')
        f.write(b'\x28\x00\x00\x00')
        f.write(struct.pack('<I', width))
        f.write(struct.pack('<I', height))
        f.write(b'\x01\x00')
        f.write(b'\x18\x00')
        f.write(b'\x00\x00\x00\x00')
        f.write(struct.pack('<I', pixel_bytes))
        f.write(b'\x00\x00\x00\x00')
        f.write(b'\x00\x00\x00\x00')
        f.write(b'\x00\x00\x00\x00')
        f.write(b'\x00\x00\x00\x00')
        pixel_data = bytes(random.randint(0, 255) for _ in range(pixel_bytes))
        f.write(pixel_data)
    return file_size

def generate_image_sizes(n, total_size, min_size=54):
    if total_size < n * min_size:
        raise ValueError("Tamaño total insuficiente para generar imágenes con tamaño mínimo.")

    # Calcular el tamaño usable después de reservar el mínimo para cada imagen
    usable_size = total_size - n * min_size
    
    # Generar tamaños aleatorios iniciales usando una distribución normal
    mean_size = usable_size / n
    std_size = mean_size / 2  # Desviación estándar para variabilidad
    sizes = np.random.normal(mean_size, std_size, n)
    
    # Asegurar que los tamaños sean positivos
    sizes = np.clip(sizes, 0, None)
    
    # Convertir a enteros y ajustar para que sean compatibles con BMP (múltiplos de 3)
    sizes = np.floor(sizes / 3) * 3  # Redondear hacia abajo al múltiplo de 3 más cercano
    
    # Agregar el tamaño mínimo
    sizes = sizes + min_size
    
    # Ajustar los tamaños para que sumen exactamente total_size
    current_total = sizes.sum()
    if current_total != total_size:
        diff = total_size - current_total
        # Distribuir la diferencia en múltiplos de 3
        steps = int(diff // 3)  # Convertir a entero
        indices = np.random.choice(n, abs(steps), replace=True)
        for idx in indices:
            sizes[idx] += 3 if diff > 0 else -3
            if sizes[idx] < min_size:
                sizes[idx] = min_size  # Asegurar que no baje del mínimo
    
    # Verificar que todos los tamaños sean válidos
    sizes = np.clip(sizes, min_size, None).astype(int)
    
    return sizes

def create_html(image_files, html_size, folder, num_images):
    html_content = '<html>\n\t<head>\n\t\t<link rel=\'shortcut icon\' href=\'data:image/x-icon;,\' type=\'image/x-icon\'> \n'
    html_content += f'\t\t<title>htmlSize: {html_size} numImgs: {num_images}</title>\n'
    html_content += '\t\t<meta charset=\'utf-8\'/>\n\t</head>\n\t<body>'
    
    text_length = random.randint(10, 50)
    random_text = ''.join(random.choices('ABCDEFGHIJKLMNOPQRSTUVWXYZ', k=text_length))
    html_content += random_text
    
    for img in image_files:
        html_content += f'<img src="{img}" />\n'
        text_length = random.randint(20, 100)
        random_text = ''.join(random.choices('ABCDEFGHIJKLMNOPQRSTUVWXYZ', k=text_length))
        html_content += random_text
    
    current_size = len(html_content.encode('utf-8'))
    if current_size < html_size:
        extra_text = 'A' * (html_size - current_size)
        html_content += extra_text
    elif current_size > html_size:
        html_content = html_content[:html_size - len('</body></html>')] + '</body></html>'
    
    html_content += '</body></html>'
    
    with open(f'{folder}/index.html', 'w') as f:
        f.write(html_content)
    return len(html_content.encode('utf-8'))

def generate_webpage(total_size_bytes, num_images, html_size):
    min_html_size = 200 + num_images * 50
    if html_size < min_html_size:
        raise ValueError(f"El tamaño del HTML ({html_size}) es insuficiente para {num_images} imágenes.")
    if total_size_bytes < html_size + num_images * 54:
        raise ValueError("El tamaño total es insuficiente para generar las imágenes y el HTML.")
    
    images_total_size = total_size_bytes - html_size
    image_sizes = generate_image_sizes(num_images, images_total_size)
    
    base_folder = f"poblation/{total_size_bytes}/{num_images}"
    os.makedirs(base_folder, exist_ok=True)
    
    index = 0
    while os.path.exists(f"{base_folder}/{index:04d}"):
        index += 1
    folder_name = f"{base_folder}/{index:04d}"
    os.makedirs(folder_name, exist_ok=True)
    
    image_files = []
    for i, size in enumerate(image_sizes):
        pixels = (size - 54) // 3
        if pixels < 1:
            pixels = 1
        final_filename = f"{folder_name}/{i+1:04d}_{size:09d}.bmp"
        actual_size = create_bmp(final_filename, size)
        image_files.append(f"{i+1:04d}_{size:09d}.bmp")
    
    actual_html_size = create_html(image_files, html_size, folder_name, num_images)
            
if __name__ == "__main__":
    for i in range(10):
        total_size = int(total_kbytes.muestra() * 1024)
        print(f"Total size: {total_size} bytes")
        for j in range(30): 
            num_images = j*2 + 5
            html_size = int(html_kbytes.muestra() * 1024)
            
            print(f"Num images: {num_images}")
            print(f"HTML size: {html_size} bytes")
            
            generate_webpage(total_size, num_images, html_size)
# Out:
# Total size: 2414154 bytes
# Num images: 5
# HTML size: 57376 bytes
# Num images: 7
# HTML size: 6355 bytes
# Num images: 9
# HTML size: 40551 bytes
# Num images: 11
# HTML size: 29599 bytes
# Num images: 13
# HTML size: 39598 bytes
# Num images: 15
# HTML size: 48636 bytes
# Num images: 17
# HTML size: 245974 bytes
# Num images: 19
# HTML size: 52387 bytes
# Num images: 21
# HTML size: 255931 bytes
# Num images: 23
# HTML size: 25859 bytes
# Num images: 25
# HTML size: 124002 bytes
# Num images: 27
# HTML size: 13311 bytes
# Num images: 29
# HTML size: 17404 bytes
# Num images: 31
# HTML size: 70183 bytes
# Num images: 33
# HTML size: 37781 bytes
# Num images: 35
# HTML size: 101824 bytes
# Num images: 37
# HTML size: 5855 bytes
# Num images: 39
# HTML size: 48623 bytes
# Num images: 41
# HTML size: 168541 bytes
# Num images: 43
# HTML size: 427038 bytes
# Num images: 45
# HTML size: 202824 bytes
# Num images: 47
# HTML size: 64178 bytes
# Num images: 49
# HTML size: 165119 bytes
# Num images: 51
# HTML size: 282247 bytes
# Num images: 53
# HTML size: 145497 bytes
# Num images: 55
# HTML size: 10611 bytes
# Num images: 57
# HTML size: 5225 bytes
# Num images: 59
# HTML size: 179970 bytes
# Num images: 61
# HTML size: 444491 bytes
# Num images: 63
# HTML size: 52047 bytes
# Total size: 800378 bytes
# Num images: 5
# HTML size: 86640 bytes
# Num images: 7
# HTML size: 46112 bytes
# Num images: 9
# HTML size: 60451 bytes
# Num images: 11
# HTML size: 247077 bytes
# Num images: 13
# HTML size: 30570 bytes
# Num images: 15
# HTML size: 83614 bytes
# Num images: 17
# HTML size: 178205 bytes
# Num images: 19
# HTML size: 142064 bytes
# Num images: 21
# HTML size: 115233 bytes
# Num images: 23
# HTML size: 7531 bytes
# Num images: 25
# HTML size: 14605 bytes
# Num images: 27
# HTML size: 78275 bytes
# Num images: 29
# HTML size: 27589 bytes
# Num images: 31
# HTML size: 197011 bytes
# Num images: 33
# HTML size: 113932 bytes
# Num images: 35
# HTML size: 142899 bytes
# Num images: 37
# HTML size: 93281 bytes
# Num images: 39
# HTML size: 85774 bytes
# Num images: 41
# HTML size: 446203 bytes
# Num images: 43
# HTML size: 433441 bytes
# Num images: 45
# HTML size: 315140 bytes
# Num images: 47
# HTML size: 25034 bytes
# Num images: 49
# HTML size: 11503 bytes
# Num images: 51
# HTML size: 29660 bytes
# Num images: 53
# HTML size: 86382 bytes
# Num images: 55
# HTML size: 128570 bytes
# Num images: 57
# HTML size: 26772 bytes
# Num images: 59
# HTML size: 94328 bytes
# Num images: 61
# HTML size: 142024 bytes
# Num images: 63
# HTML size: 60502 bytes
# Total size: 511828 bytes
# Num images: 5
# HTML size: 35717 bytes
# Num images: 7
# HTML size: 417625 bytes
# Num images: 9
# HTML size: 77740 bytes
# Num images: 11
# HTML size: 35557 bytes
# Num images: 13
# HTML size: 10014 bytes
# Num images: 15
# HTML size: 98940 bytes
# Num images: 17
# HTML size: 84972 bytes
# Num images: 19
# HTML size: 33563 bytes
# Num images: 21
# HTML size: 10571 bytes
# Num images: 23
# HTML size: 56837 bytes
# Num images: 25
# HTML size: 138980 bytes
# Num images: 27
# HTML size: 157014 bytes
# Num images: 29
# HTML size: 5706 bytes
# Num images: 31
# HTML size: 35020 bytes
# Num images: 33
# HTML size: 67453 bytes
# Num images: 35
# HTML size: 118766 bytes
# Num images: 37
# HTML size: 7236 bytes
# Num images: 39
# HTML size: 10431 bytes
# Num images: 41
# HTML size: 61337 bytes
# Num images: 43
# HTML size: 58318 bytes
# Num images: 45
# HTML size: 100521 bytes
# Num images: 47
# HTML size: 337829 bytes
# Num images: 49
# HTML size: 13705 bytes
# Num images: 51
# HTML size: 20642 bytes
# Num images: 53
# HTML size: 50719 bytes
# Num images: 55
# HTML size: 143987 bytes
# Num images: 57
# HTML size: 11849 bytes
# Num images: 59
# HTML size: 124199 bytes
# Num images: 61
# HTML size: 67307 bytes
# Num images: 63
# HTML size: 148254 bytes
# Total size: 3734496 bytes
# Num images: 5
# HTML size: 71221 bytes
# Num images: 7
# HTML size: 98025 bytes
# Num images: 9
# HTML size: 22818 bytes
# Num images: 11
# HTML size: 13405 bytes
# Num images: 13
# HTML size: 347930 bytes
# Num images: 15
# HTML size: 5570 bytes
# Num images: 17
# HTML size: 17861 bytes
# Num images: 19
# HTML size: 35725 bytes
# Num images: 21
# HTML size: 293076 bytes
# Num images: 23
# HTML size: 19216 bytes
# Num images: 25
# HTML size: 12646 bytes
# Num images: 27
# HTML size: 74641 bytes
# Num images: 29
# HTML size: 6740 bytes
# Num images: 31
# HTML size: 259579 bytes
# Num images: 33
# HTML size: 64031 bytes
# Num images: 35
# HTML size: 106797 bytes
# Num images: 37
# HTML size: 280509 bytes
# Num images: 39
# HTML size: 189827 bytes
# Num images: 41
# HTML size: 128886 bytes
# Num images: 43
# HTML size: 18453 bytes
# Num images: 45
# HTML size: 60550 bytes
# Num images: 47
# HTML size: 14906 bytes
# Num images: 49
# HTML size: 349427 bytes
# Num images: 51
# HTML size: 56133 bytes
# Num images: 53
# HTML size: 9682 bytes
# Num images: 55
# HTML size: 119122 bytes
# Num images: 57
# HTML size: 253198 bytes
# Num images: 59
# HTML size: 132133 bytes
# Num images: 61
# HTML size: 22424 bytes
# Num images: 63
# HTML size: 13864 bytes
# Total size: 798283 bytes
# Num images: 5
# HTML size: 43749 bytes
# Num images: 7
# HTML size: 111105 bytes
# Num images: 9
# HTML size: 233098 bytes
# Num images: 11
# HTML size: 147130 bytes
# Num images: 13
# HTML size: 144892 bytes
# Num images: 15
# HTML size: 39834 bytes
# Num images: 17
# HTML size: 106866 bytes
# Num images: 19
# HTML size: 67999 bytes
# Num images: 21
# HTML size: 145109 bytes
# Num images: 23
# HTML size: 108051 bytes
# Num images: 25
# HTML size: 46240 bytes
# Num images: 27
# HTML size: 173236 bytes
# Num images: 29
# HTML size: 85742 bytes
# Num images: 31
# HTML size: 369895 bytes
# Num images: 33
# HTML size: 38267 bytes
# Num images: 35
# HTML size: 120041 bytes
# Num images: 37
# HTML size: 309768 bytes
# Num images: 39
# HTML size: 376599 bytes
# Num images: 41
# HTML size: 337242 bytes
# Num images: 43
# HTML size: 8585 bytes
# Num images: 45
# HTML size: 315171 bytes
# Num images: 47
# HTML size: 87022 bytes
# Num images: 49
# HTML size: 64031 bytes
# Num images: 51
# HTML size: 252577 bytes
# Num images: 53
# HTML size: 68053 bytes
# Num images: 55
# HTML size: 23324 bytes
# Num images: 57
# HTML size: 21976 bytes
# Num images: 59
# HTML size: 15483 bytes
# Num images: 61
# HTML size: 8080 bytes
# Num images: 63
# HTML size: 51695 bytes
# Total size: 3871694 bytes
# Num images: 5
# HTML size: 136205 bytes
# Num images: 7
# HTML size: 7716 bytes
# Num images: 9
# HTML size: 15948 bytes
# Num images: 11
# HTML size: 64821 bytes
# Num images: 13
# HTML size: 12459 bytes
# Num images: 15
# HTML size: 217828 bytes
# Num images: 17
# HTML size: 105046 bytes
# Num images: 19
# HTML size: 123092 bytes
# Num images: 21
# HTML size: 105962 bytes
# Num images: 23
# HTML size: 4391 bytes
# Num images: 25
# HTML size: 108182 bytes
# Num images: 27
# HTML size: 19172 bytes
# Num images: 29
# HTML size: 76289 bytes
# Num images: 31
# HTML size: 270268 bytes
# Num images: 33
# HTML size: 7751 bytes
# Num images: 35
# HTML size: 6573 bytes
# Num images: 37
# HTML size: 6633 bytes
# Num images: 39
# HTML size: 19745 bytes
# Num images: 41
# HTML size: 61972 bytes
# Num images: 43
# HTML size: 12694 bytes
# Num images: 45
# HTML size: 6190 bytes
# Num images: 47
# HTML size: 47240 bytes
# Num images: 49
# HTML size: 7932 bytes
# Num images: 51
# HTML size: 226500 bytes
# Num images: 53
# HTML size: 54057 bytes
# Num images: 55
# HTML size: 21695 bytes
# Num images: 57
# HTML size: 114453 bytes
# Num images: 59
# HTML size: 289890 bytes
# Num images: 61
# HTML size: 62211 bytes
# Num images: 63
# HTML size: 139374 bytes
# Total size: 4052310 bytes
# Num images: 5
# HTML size: 56548 bytes
# Num images: 7
# HTML size: 38179 bytes
# Num images: 9
# HTML size: 375174 bytes
# Num images: 11
# HTML size: 93314 bytes
# Num images: 13
# HTML size: 17876 bytes
# Num images: 15
# HTML size: 14111 bytes
# Num images: 17
# HTML size: 231548 bytes
# Num images: 19
# HTML size: 92188 bytes
# Num images: 21
# HTML size: 4527 bytes
# Num images: 23
# HTML size: 6894 bytes
# Num images: 25
# HTML size: 105867 bytes
# Num images: 27
# HTML size: 172714 bytes
# Num images: 29
# HTML size: 30982 bytes
# Num images: 31
# HTML size: 202380 bytes
# Num images: 33
# HTML size: 62413 bytes
# Num images: 35
# HTML size: 19623 bytes
# Num images: 37
# HTML size: 270497 bytes
# Num images: 39
# HTML size: 163925 bytes
# Num images: 41
# HTML size: 29096 bytes
# Num images: 43
# HTML size: 52573 bytes
# Num images: 45
# HTML size: 46110 bytes
# Num images: 47
# HTML size: 6164 bytes
# Num images: 49
# HTML size: 9641 bytes
# Num images: 51
# HTML size: 52710 bytes
# Num images: 53
# HTML size: 107109 bytes
# Num images: 55
# HTML size: 387573 bytes
# Num images: 57
# HTML size: 8291 bytes
# Num images: 59
# HTML size: 29775 bytes
# Num images: 61
# HTML size: 97738 bytes
# Num images: 63
# HTML size: 424301 bytes
# Total size: 2771049 bytes
# Num images: 5
# HTML size: 124050 bytes
# Num images: 7
# HTML size: 120022 bytes
# Num images: 9
# HTML size: 67227 bytes
# Num images: 11
# HTML size: 152471 bytes
# Num images: 13
# HTML size: 140858 bytes
# Num images: 15
# HTML size: 213266 bytes
# Num images: 17
# HTML size: 64640 bytes
# Num images: 19
# HTML size: 49945 bytes
# Num images: 21
# HTML size: 82178 bytes
# Num images: 23
# HTML size: 6404 bytes
# Num images: 25
# HTML size: 291191 bytes
# Num images: 27
# HTML size: 58955 bytes
# Num images: 29
# HTML size: 92020 bytes
# Num images: 31
# HTML size: 17712 bytes
# Num images: 33
# HTML size: 132519 bytes
# Num images: 35
# HTML size: 28142 bytes
# Num images: 37
# HTML size: 146260 bytes
# Num images: 39
# HTML size: 48303 bytes
# Num images: 41
# HTML size: 20200 bytes
# Num images: 43
# HTML size: 19654 bytes
# Num images: 45
# HTML size: 109603 bytes
# Num images: 47
# HTML size: 57607 bytes
# Num images: 49
# HTML size: 15313 bytes
# Num images: 51
# HTML size: 54258 bytes
# Num images: 53
# HTML size: 406695 bytes
# Num images: 55
# HTML size: 4431 bytes
# Num images: 57
# HTML size: 249850 bytes
# Num images: 59
# HTML size: 83101 bytes
# Num images: 61
# HTML size: 197092 bytes
# Num images: 63
# HTML size: 13008 bytes
# Total size: 7638443 bytes
# Num images: 5
# HTML size: 12422 bytes
# Num images: 7
# HTML size: 14671 bytes
# Num images: 9
# HTML size: 19063 bytes
# Num images: 11
# HTML size: 21904 bytes
# Num images: 13
# HTML size: 108800 bytes
# Num images: 15
# HTML size: 44159 bytes
# Num images: 17
# HTML size: 138932 bytes
# Num images: 19
# HTML size: 390279 bytes
# Num images: 21
# HTML size: 62881 bytes
# Num images: 23
# HTML size: 289778 bytes
# Num images: 25
# HTML size: 135844 bytes
# Num images: 27
# HTML size: 434585 bytes
# Num images: 29
# HTML size: 287704 bytes
# Num images: 31
# HTML size: 124810 bytes
# Num images: 33
# HTML size: 36723 bytes
# Num images: 35
# HTML size: 5791 bytes
# Num images: 37
# HTML size: 15413 bytes
# Num images: 39
# HTML size: 7180 bytes
# Num images: 41
# HTML size: 447105 bytes
# Num images: 43
# HTML size: 181476 bytes
# Num images: 45
# HTML size: 59531 bytes
# Num images: 47
# HTML size: 96557 bytes
# Num images: 49
# HTML size: 18405 bytes
# Num images: 51
# HTML size: 55123 bytes
# Num images: 53
# HTML size: 16793 bytes
# Num images: 55
# HTML size: 6249 bytes
# Num images: 57
# HTML size: 10588 bytes
# Num images: 59
# HTML size: 123571 bytes
# Num images: 61
# HTML size: 255577 bytes
# Num images: 63
# HTML size: 433813 bytes
# Total size: 9239647 bytes
# Num images: 5
# HTML size: 105721 bytes
# Num images: 7
# HTML size: 138082 bytes
# Num images: 9
# HTML size: 115182 bytes
# Num images: 11
# HTML size: 18104 bytes
# Num images: 13
# HTML size: 15112 bytes
# Num images: 15
# HTML size: 326645 bytes
# Num images: 17
# HTML size: 50278 bytes
# Num images: 19
# HTML size: 315450 bytes
# Num images: 21
# HTML size: 55012 bytes
# Num images: 23
# HTML size: 258761 bytes
# Num images: 25
# HTML size: 40763 bytes
# Num images: 27
# HTML size: 79709 bytes
# Num images: 29
# HTML size: 276851 bytes
# Num images: 31
# HTML size: 68257 bytes
# Num images: 33
# HTML size: 23534 bytes
# Num images: 35
# HTML size: 211134 bytes
# Num images: 37
# HTML size: 115837 bytes
# Num images: 39
# HTML size: 9610 bytes
# Num images: 41
# HTML size: 239242 bytes
# Num images: 43
# HTML size: 392520 bytes
# Num images: 45
# HTML size: 299766 bytes
# Num images: 47
# HTML size: 17843 bytes
# Num images: 49
# HTML size: 12525 bytes
# Num images: 51
# HTML size: 99071 bytes
# Num images: 53
# HTML size: 91830 bytes
# Num images: 55
# HTML size: 19553 bytes
# Num images: 57
# HTML size: 121707 bytes
# Num images: 59
# HTML size: 5698 bytes
# Num images: 61
# HTML size: 51208 bytes
# Num images: 63
# HTML size: 6849 bytes
